# %% [markdown]
# # Analysis of 2nd torus model optimization to match FC region

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import Range1d, Span
from bokeh.palettes import Dark2_5 as palette
from bokeh.layouts import gridplot
from bokeh.charts import Scatter

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="f125b5e7-ec16-4e83-992b-904b05c75488">Loading BokehJS ...</span>
#     </div>

# %%
import logging
logging.basicConfig(format='%(levelname)s: %(message)s', level=logging.DEBUG)

# %%
import os
import sys

import numpy as np

# %%
iq_goal_fname = 'data/lysozyme_00001.iq'
assert os.path.exists(iq_goal_fname)
iq_goal = np.loadtxt(iq_goal_fname)

iq_model_fname = 'lys_ellipsoid/lys_ellipsoid_00001.iq'
assert os.path.exists(iq_model_fname)
iq_model = np.loadtxt(iq_model_fname)

# %%
p1 = figure(width=400, height=400, x_axis_label='q (1/A)', y_axis_label='I(q)', x_axis_type='log', y_axis_type='log')
p2 = figure(width=400, height=400, x_axis_label='q (1/A)', y_axis_label='I(q)')

p1.line(iq_goal[:, 0], iq_goal[:, 1], color=palette[0], line_width=2, line_dash=[4, 0], legend='experiment')
p1.line(iq_model[:, 0], iq_model[:, 1], color=palette[1], line_width=2, line_dash=[4, 4], legend='22.5x15x15 model')
p2.line(iq_goal[:, 0], iq_goal[:, 1], color=palette[0], line_width=2, line_dash=[4, 0], legend='experiment')
p2.line(iq_model[:, 0], iq_model[:, 1], color=palette[1], line_width=2, line_dash=[4, 4], legend='22.5x15x15 model')

x_range = (iq_goal[1, 0], iq_goal[-1, 0])
y_range = (min(iq_goal[:, 1]) * 0.5, iq_goal[1, 1] * 1.5)
logging.debug('x range: {}'.format(x_range))
logging.debug('y range: {}'.format(y_range))
p1.x_range = Range1d(*x_range)
p1.y_range = Range1d(*y_range)
p2.x_range = p1.x_range
p2.y_range = p1.y_range
p1.legend.location = 'bottom_left'

plots = gridplot([[p1, p2]])
show(plots)
# Out:
# DEBUG: x range: (0.0050000000000000001, 0.29999999999999999)
# DEBUG: y range: (0.0038509999999999998, 1.4977845000000001)
#     <div class="bk-root">
#         <div class="plotdiv" id="b2489985-bc35-4396-ae84-69063005196b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#b2489985-bc35-4396-ae84-69063005196b").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b2489985-bc35-4396-ae84-69063005196b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b2489985-bc35-4396-ae84-69063005196b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f1805bc5-2d23-4659-a9f4-c0f697e2dac3":{"roots":{"references":[{"attributes":{"children":[{"id":"9c7024ad-9232-4d5c-9be4-6b993e373085","subtype":"Figure","type":"Plot"},{"id":"2fe4837f-9c29-41fb-9f0c-84f20954bcfc","subtype":"Figure","type":"Plot"}]},"id":"b2a11476-4a6b-4646-8d59-62f6b06d0986","type":"Row"},{"attributes":{"callback":null,"end":0.3,"start":0.005},"id":"48834678-1966-4cbe-b432-4ad649b265f8","type":"Range1d"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[4,0],"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"66540547-d9dd-48aa-8645-fc519717cd48","type":"Line"},{"attributes":{"items":[{"id":"8cea209e-b02f-4897-bb12-39555a034071","type":"LegendItem"},{"id":"8e6883eb-c3ef-468c-b2c4-de2eb6aa2c22","type":"LegendItem"}],"plot":{"id":"2fe4837f-9c29-41fb-9f0c-84f20954bcfc","subtype":"Figure","type":"Plot"}},"id":"67ebeba5-2df1-4371-80a4-73474427618e","type":"Legend"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"054451cd-6fc0-43c8-b60a-3398b1debcc6","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.0,0.005,0.01,0.015,0.02,0.025,0.03,0.035,0.04,0.045,0.05,0.055,0.06,0.065,0.07,0.075,0.08,0.085,0.09,0.095,0.1,0.105,0.11,0.115,0.12,0.125,0.13,0.135,0.14,0.145,0.15,0.155,0.16,0.165,0.17,0.175,0.18,0.185,0.19,0.195,0.2,0.205,0.21,0.215,0.22,0.225,0.23,0.235,0.24,0.245,0.25,0.255,0.26,0.265,0.27,0.275,0.28,0.285,0.29,0.295,0.3],"y":[1.0,0.9984,0.993613,0.985682,0.974675,0.96069,0.943847,0.924291,0.902188,0.877725,0.851103,0.822542,0.792269,0.760522,0.727546,0.693586,0.658891,0.623705,0.588266,0.552805,0.517545,0.482693,0.448445,0.414981,0.382461,0.351032,0.320819,0.291929,0.264451,0.238454,0.213989,0.191088,0.169768,0.150028,0.131855,0.11522,0.100082,0.086392,0.074089,0.063106,0.05337,0.044803,0.037325,0.030852,0.025301,0.020589,0.016635,0.013359,0.010685,0.008542,0.00686,0.005576,0.004631,0.003972,0.003548,0.003316,0.003236,0.003275,0.003401,0.003588,0.003815]}},"id":"d633bc8d-3cf5-4589-9fb7-34e3cbf33b47","type":"ColumnDataSource"},{"attributes":{"label":{"value":"experiment"},"renderers":[{"id":"929cb99e-a756-40cc-9d65-2e29631f1954","type":"GlyphRenderer"}]},"id":"8cea209e-b02f-4897-bb12-39555a034071","type":"LegendItem"},{"attributes":{"plot":{"id":"2fe4837f-9c29-41fb-9f0c-84f20954bcfc","subtype":"Figure","type":"Plot"}},"id":"786510bc-b2f9-46f6-b2aa-2cecaabec5ce","type":"PanTool"},{"attributes":{"plot":null,"text":null},"id":"a6f0884b-7682-4464-832b-e197029cad63","type":"Title"},{"attributes":{"plot":{"id":"9c7024ad-9232-4d5c-9be4-6b993e373085","subtype":"Figure","type":"Plot"}},"id":"5a57872f-9e0d-4df2-8219-72464bf66495","type":"ResetTool"},{"attributes":{"plot":{"id":"9c7024ad-9232-4d5c-9be4-6b993e373085","subtype":"Figure","type":"Plot"}},"id":"eb835485-fbe1-4892-ac44-6664a73aba1c","type":"PanTool"},{"attributes":{"label":{"value":"22.5x15x15 model"},"renderers":[{"id":"70291510-4db4-489c-9c83-de76c44449c4","type":"GlyphRenderer"}]},"id":"8e6883eb-c3ef-468c-b2c4-de2eb6aa2c22","type":"LegendItem"},{"attributes":{"items":[{"id":"04d9a65a-4672-4530-8dc0-cbd0e8ca5a7a","type":"LegendItem"},{"id":"b6c9e069-42c1-48a9-b4b7-ebf98aefd55f","type":"LegendItem"}],"location":"bottom_left","plot":{"id":"9c7024ad-9232-4d5c-9be4-6b993e373085","subtype":"Figure","type":"Plot"}},"id":"43debc55-9660-42c8-a10c-7e72af3bf818","type":"Legend"},{"attributes":{"line_color":{"value":"#1b9e77"},"line_dash":[4,0],"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"c36e2df9-595d-429e-b38c-83b738a7867c","type":"Line"},{"attributes":{"callback":null,"end":1.4977845,"start":0.003851},"id":"44918710-4f41-4b6f-bb9a-b0f24b05c87a","type ...

# %%
import sasmol.sasmol as sasmol
atom = sasmol.SasMol(0)
atom.read_pdb('data/lysozyme_centered.pdb')
atom_rg = atom.calcrg(0)

model = sasmol.SasMol(0)
model.read_pdb('lys_ellipsoid/lys_ellipsoid_z.pdb')
model_rg = model.calcrg(0)

logging.debug('atomistic Rg: {}'.format(atom_rg))
logging.debug('model Rg: {}'.format(model_rg))
# Out:
# DEBUG: atomistic Rg: 13.9946706991
# DEBUG: model Rg: 13.8646412507
# reading filename:  data/lysozyme_centered.pdb
# num_atoms =  1960
# >>> found  1  model(s) or frame(s)
# finished reading frame =  1
# reading filename:  lys_ellipsoid/lys_ellipsoid_z.pdb
# num_atoms =  2000
# >>> found  1  model(s) or frame(s)
# finished reading frame =  1

# %%
import pandas as pd
run_dir = 'lys_ellipsoid_scan1'

log_fname = os.path.join(run_dir, 'sx13to17_sy13to17_sz20.5to24.5.log')
log = pd.read_csv(log_fname, delimiter='\t', index_col=[0], escapechar='#')
log.rename(columns=lambda x: x.strip(), inplace=True)

r_fname = os.path.join(run_dir, 'sascalc/neutron_D2Op_100/pdb_r_factors.txt')
r = pd.read_csv(r_fname, delimiter='\t', index_col=[0])
r.rename(columns=lambda x: x.strip(), inplace=True)

# %%
r.head()
# Out:
#           r                                             fnames
# 1  0.063434  lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 2  0.038537  lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 3  0.032567  lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 4  0.017184  lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 5  0.018528  lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...

# %%
log.head()
# Out:
#                 rg    sx    sy    sz
#  frame
# 1        12.320748  13.0  13.0  20.5
# 2        12.507873  13.0  14.0  20.5
# 3        12.706000  13.0  15.0  20.5
# 4        13.069334  13.0  16.0  20.5
# 5        13.311778  13.0  17.0  20.5

# %%
result = pd.concat([log, r], axis=1)

# %%
result.head()
# Out:
#                 rg    sx    sy    sz         r  \
#  frame
# 1        12.320748  13.0  13.0  20.5  0.063434
# 2        12.507873  13.0  14.0  20.5  0.038537
# 3        12.706000  13.0  15.0  20.5  0.032567
# 4        13.069334  13.0  16.0  20.5  0.017184
# 5        13.311778  13.0  17.0  20.5  0.018528
#
#                                                     fnames
#  frame
# 1        lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 2        lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 3        lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 4        lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 5        lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...

# %%
i_best = result['r'].idxmin()
i_worst = result['r'].idxmax()
logging.info('\nbest: {}\nworst: {}'.format(i_best, i_worst))
# Out:
# INFO:
# best: 56
# worst: 125

# %%
result[result.sz == 22.5]
# Out:
#                 rg    sx    sy    sz         r  \
#  frame
# 51       13.072000  13.0  13.0  22.5  0.022476
# 52       13.169300  13.0  14.0  22.5  0.007421
# 53       13.434784  13.0  15.0  22.5  0.019585
# 54       13.612343  13.0  16.0  22.5  0.033431
# 55       13.655938  13.0  17.0  22.5  0.065439
# 56       13.336388  14.0  13.0  22.5  0.006302
# 57       13.282775  14.0  14.0  22.5  0.016416
# 58       13.706066  14.0  15.0  22.5  0.034617
# 59       13.754028  14.0  16.0  22.5  0.059181
# 60       14.115566  14.0  17.0  22.5  0.075246
# 61       13.331443  15.0  13.0  22.5  0.013015
# 62       13.551821  15.0  14.0  22.5  0.045061
# 63       13.739766  15.0  15.0  22.5  0.049944
# 64       14.103090  15.0  16.0  22.5  0.074858
# 65       14.213501  15.0  17.0  22.5  0.087904
# 66       13.609174  16.0  13.0  22.5  0.039536
# 67       13.816483  16.0  14.0  22.5  0.054082
# 68       13.932842  16.0  15.0  22.5  0.070094
# 69       14.352348  16.0  16.0  22.5  0.098956
# 70       14.436283  16.0  17.0  22.5  0.108903
# 71       13.752767  17.0  13.0  22.5  0.049507
# 72       14.059171  17.0  14.0  22.5  0.064841
# 73       14.357898  17.0  15.0  22.5  0.095165
# 74       14.485272  17.0  16.0  22.5  0.103731
# 75       14.674119  17.0  17.0  22.5  0.112636
#
#                                                     fnames
#  frame
# 51       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 52       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 53       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 54       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 55       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 56       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 57       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 58       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 59       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 60       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 61       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 62       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 63       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 64       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 65       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 66       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 67       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 68       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 69       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 70       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 71       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 72       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 73       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 74       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...
# 75       lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/l...

# %%
result.columns
# Out:
# Index([u'rg', u'sx', u'sy', u'sz', u'r', u'fnames'], dtype='object')

# %%
import glob

# %%
goal_fname = 'data/lysozyme_00001.iq'
goal_iq = np.loadtxt(goal_fname)[:, :2]
nq, _ = goal_iq.shape

# %%
run_dir = 'lys_ellipsoid_scan1/sascalc/neutron_D2Op_100/'
ext = '*.iq'
file_search = os.path.join(run_dir, ext)
iq_fnames = glob.glob(file_search)
assert iq_fnames, 'ERROR: no files found using {}'.format(file_search)
iq_fnames.sort()

iq_data = np.empty((nq, len(iq_fnames)+1), order='F')
iq_data[:, 0] = goal_iq[:, 0]
for i, fname in enumerate(iq_fnames):
    this_iq_data = np.loadtxt(fname)
    iq_data[:, i+1] = this_iq_data[:, 1] * iq_goal[0, 1] / this_iq_data[0, 1]

# %%
p1 = Scatter(result, x='rg', y='r', color=palette[1], width=400, height=400, 
             xlabel='Rg (A)', ylabel='R-factor')
vline = Span(location=atom_rg, dimension='height', line_color=palette[0], line_width=3)
p1.renderers.extend([vline])

p2 = figure(width=400, height=400, x_axis_label='q (1/A)', y_axis_label='I(q)') #, x_axis_type='log', y_axis_type='log')

# for i in xrange(len(iq_fnames)):
#     p2.line(iq_data[:, 0], iq_data[:, i+1], color='black', line_width=2, legend='scan')
p2.line(iq_goal[:, 0], iq_goal[:, 1], color=palette[0], line_width=2, line_dash=[6, 6], 
        legend='experiment')
p2.line(iq_data[:, 0], iq_data[:, i_best], color=palette[1], line_width=2, line_dash=[5, 1], 
        legend='best')
p2.line(iq_model[:, 0], iq_model[:, 1], color=palette[2], line_width=2, 
        legend='22.5x15x15 model')
p2.line(iq_data[:, 0], iq_data[:, i_worst], color=palette[3], line_width=2, line_dash=[4, 2, 2], 
        legend='worst')

x_range = (iq_goal[1, 0], iq_goal[-1, 0])
y_range = (min(iq_goal[:, 1]) * 0.5, iq_goal[1, 1] * 1.5)
logging.debug('x range: {}'.format(x_range))
logging.debug('y range: {}'.format(y_range))
p2.x_range = Range1d(*x_range)
p2.y_range = Range1d(*y_range)
#p2.legend.location = 'bottom_left'

plots = gridplot([[p1, p2]])
show(plots)
# Out:
# DEBUG: x range: (0.0050000000000000001, 0.29999999999999999)
# DEBUG: y range: (0.0038509999999999998, 1.4977845000000001)
#     <div class="bk-root">
#         <div class="plotdiv" id="af9ef0c4-c984-401e-92e3-6881408fa375"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#af9ef0c4-c984-401e-92e3-6881408fa375").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("af9ef0c4-c984-401e-92e3-6881408fa375");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'af9ef0c4-c984-401e-92e3-6881408fa375' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"b2ce072a-48ba-4668-bbe9-3547e305d286":{"roots":{"references":[{"attributes":{"axis_label":"R-factor","formatter":{"id":"238993e8-8c8f-4a91-a8f3-faf5fb752a3c","type":"BasicTickFormatter"},"plot":{"id":"6ec88be8-22f7-463b-94e2-2f92bf20633d","subtype":"Chart","type":"Plot"},"ticker":{"id":"d9b49120-342e-47ff-ade9-56b65daa879d","type":"BasicTicker"}},"id":"b4cd2c5c-e7d6-4849-8757-add6a6493cf9","type":"LinearAxis"},{"attributes":{"axis_label":"I(q)","formatter":{"id":"ff443e23-4551-4b6c-af87-a0bfba6cee7c","type":"BasicTickFormatter"},"plot":{"id":"3b77ac9b-7416-4450-9121-06c8fdefd931","subtype":"Figure","type":"Plot"},"ticker":{"id":"2656ca5b-02c7-48f5-b217-1a059476b038","type":"BasicTicker"}},"id":"a5863fd6-432e-4622-8408-9db8774d8571","type":"LinearAxis"},{"attributes":{"plot":{"id":"3b77ac9b-7416-4450-9121-06c8fdefd931","subtype":"Figure","type":"Plot"}},"id":"3d518ad6-0cd6-4c61-a955-126d95db84e0","type":"SaveTool"},{"attributes":{},"id":"238993e8-8c8f-4a91-a8f3-faf5fb752a3c","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"c3fe9357-1e65-417f-bd5f-f0dd890117c4","type":"BoxAnnotation"},"plot":{"id":"6ec88be8-22f7-463b-94e2-2f92bf20633d","subtype":"Chart","type":"Plot"}},"id":"b1be3218-ae13-4798-94d6-e764f773c432","type":"BoxZoomTool"},{"attributes":{"line_color":{"value":"#e7298a"},"line_dash":[4,2,2],"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"4a2df8f9-a041-4d33-a256-c93e4749f3f4","type":"Line"},{"attributes":{},"id":"cdb7d1cb-9f11-440d-a3c3-4c51c07bc3ca","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.0,0.005,0.01,0.015,0.02,0.025,0.03,0.035,0.04,0.045,0.05,0.055,0.06,0.065,0.07,0.075,0.08,0.085,0.09,0.095,0.1,0.105,0.11,0.115,0.12,0.125,0.13,0.135,0.14,0.145,0.15,0.155,0.16,0.165,0.17,0.175,0.18,0.185,0.19,0.195,0.2,0.205,0.21,0.215,0.22,0.225,0.23,0.235,0.24,0.245,0.25,0.255,0.26,0.265,0.27,0.275,0.28,0.285,0.29,0.295,0.3],"y":[1.0,0.9984,0.993613,0.985682,0.974675,0.96069,0.943847,0.924291,0.902188,0.877725,0.851103,0.822542,0.792269,0.760522,0.727546,0.693586,0.658891,0.623705,0.588266,0.552805,0.517545,0.482693,0.448445,0.414981,0.382461,0.351032,0.320819,0.291929,0.264451,0.238454,0.213989,0.191088,0.169768,0.150028,0.131855,0.11522,0.100082,0.086392,0.074089,0.063106,0.05337,0.044803,0.037325,0.030852,0.025301,0.020589,0.016635,0.013359,0.010685,0.008542,0.00686,0.005576,0.004631,0.003972,0.003548,0.003316,0.003236,0.003275,0.003401,0.003588,0.003815]}},"id":"886094fa-9bcb-45f2-b8fe-608c891840e8","type":"ColumnDataSource"},{"attributes":{"callback":null,"end":1.4977845,"start":0.003851},"id":"b5427be8-6ab0-44bc-93a1-92a4058da8c5","type":"Range1d"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#d95f02"},"line_color":{"value":"#d95f02"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"86f7f629-e052-47f1-bc70-0ac5d2200d74","type":"Circle"},{"attributes":{},"id":"2656ca5b-02c7-48f5-b217-1a059476b038","type":"BasicTicker"},{"attributes":{"data_source":{"id":"6124d7e3-85ce-494f-84d9-2795c358345d","type":"ColumnDataSource"},"glyph":{"id":"c067a903-0d55-49cc-94f6-23278d6d3776","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"c9767b8d-d6a0-4b25-8f8f-85deca5f7ee6","type":"Line"},"selection_glyph":null},"id":"30945415-3058-4aa7-ae1c-122c63377f99","type":"GlyphRenderer"},{"attributes":{"plot":{"id":"6ec88be8-22f7-463b-94e2-2f92bf20633d","subtype":"Chart","type":"Plot"}},"id":"e222d768-6da6-4b94-8e01-3029b76807fb","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"6ec88be8-22f7-463b-94e2-2f92bf20633d","subtype":"Chart","type":"Plot"},"ticker":{"id":"ec7d863b-0030-462c-99e3-11a388db2920","type":"BasicTicker"}},"id":"0ab6feb6-03b9-47ee-97ff-5366c92da65e","type":"Grid"},{"attributes":{"plot":{"id":"3b77ac9b-7416-4450-9121-06c8fdefd931","subtype":"Figure","type":"Plot"}},"id":"cabd7bf6-f1b8-4128-acab-53c226870b13","type":"WheelZoomTool"},{"attri ...

# %% [markdown]
# 1. Does Rg from the Guinier of the I(q) curves match the pdb structures

# %%
r_factors = pd.read_csv('./lys_ellipsoid_r1/r_factors.log', delimiter=':', index_col=[0], names=['log_level', 'label', 'r'])
r_factors.head
r_factors.head()
i_min = r_factors.r.idxmin()

# r_factors.loc[i_min]
logging.info('i min: {}'.format(i_min))
logging.info('r min:\n{}'.format(r_factors.loc[i_min]))
# Out:
# INFO: i min: 1770
# INFO: r min:
# log_level         DEBUG
# label          R-factor
# r            0.00758195
# Name: 1770, dtype: object

# %% [markdown]
# ```
# DEBUG: parameters:
# [[  9.85495473   0.           0.           0.        ]
#  [  0.           5.82059941   0.           0.        ]
#  [  0.           0.          14.18517289   0.        ]
#  [  0.           0.           0.           1.        ]]
# DEBUG: R-factor: 0.00758195057103
# ```
