# %% [markdown]
# # Lysozyme PDB
# ## Determine ellipsoid geometry that will reproduce the theoretical scattering of the Lysozyme PDB (lysozyme_centered.pdb)

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import Range1d, Span
from bokeh.palettes import Colorblind8 as palette
from bokeh.layouts import gridplot
from bokeh.charts import Scatter

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4df2763d-8a70-4fc9-9995-f9b0adb3d9a6">Loading BokehJS ...</span>
#     </div>

# %%
from sas_modeling.make_figures import solarized as palette

# %%
import logging
logging.basicConfig(format='%(levelname)s: %(message)s', level=logging.DEBUG)

# %%
import os
import sys
import numpy as np

# %% [markdown]
# ## Comaparison to the 22.5 A x 15 A x 15 A ellipsoid
# The plots below compare the theoretical scattering from the Lysozyme PDB (`lysozyme_centered.pdb`) and an ellipsoid with dimensions matching what Monica cited from Yun Liu.

# %% [markdown]
# theoretical scattering from the PDB

# %%
# iq_goal_fname = 'data/lysozyme_00001.iq'
# assert os.path.exists(iq_goal_fname)
# iq_goal = np.loadtxt(iq_goal_fname)

# %%
iq_goal_fname = 'data/exp_lys/rebinned_12_exp_data_lysozyme.dat'
assert os.path.exists(iq_goal_fname)
iq_goal = np.loadtxt(iq_goal_fname)

# %% [markdown]
# theoretical scattering from Yun Liu's ellipsoid definition (22.5 A x 15 A x 15 A)

# %%
iq_model_fname = 'lys_ellipsoid/lys_ellipsoid_00001.iq'
assert os.path.exists(iq_model_fname)
iq_model = np.loadtxt(iq_model_fname)

# %%
p2 = figure(width=400, height=400, x_axis_label='q (1/A)', y_axis_label='I(q)', x_axis_type='log', y_axis_type='log')
p1 = figure(width=400, height=400, x_axis_label='q (1/A)', y_axis_label='I(q)')

p1.line(iq_goal[:, 0], iq_goal[:, 1], color=palette[0], line_width=2, line_dash=[4, 0], legend='experiment')
p1.line(iq_model[:, 0], iq_model[:, 1], color=palette[1], line_width=2, line_dash=[4, 4], legend='22.5x15x15 model')
p2.line(iq_goal[:, 0], iq_goal[:, 1], color=palette[0], line_width=2, line_dash=[4, 0], legend='experiment')
p2.line(iq_model[:, 0], iq_model[:, 1], color=palette[1], line_width=2, line_dash=[4, 4], legend='22.5x15x15 model')

x_range = (iq_goal[1, 0], iq_goal[-1, 0])
y_range = (min(iq_goal[:, 1]) * 0.5, max(iq_goal[:, 1]) * 1.1)
logging.debug('x range: {}'.format(x_range))
logging.debug('y range: {}'.format(y_range))
p1.x_range = Range1d(*x_range)
p1.y_range = Range1d(*y_range)
p2.x_range = p1.x_range
p2.y_range = p1.y_range
p2.legend.location = 'bottom_left'

plots = gridplot([[p1, p2]])
show(plots)
# Out:
# DEBUG: x range: (0.036364, 0.40000000000000002)
# DEBUG: y range: (5.8035833333333331e-05, 0.012320000000000001)
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="152bcaad-511c-4808-a4e0-902690cfd2fb"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("152bcaad-511c-4808-a4e0-902690cfd2fb");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("152bcaad-511c-4808-a4e0-902690cfd2fb");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '152bcaad-511c-4808-a4e0-902690cfd2fb' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"29a1cee6-d512-4387-938e-cfde94a4fcaa":{"roots":{"references":[{"attributes":{"label":{"value":"22.5x15x15 model"},"renderers":[{"id":"cb420ce6-426b-40d9-b6e0-60a903162b1e","type":"GlyphRenderer"}]},"id":"bd2138a7-339b-4a7c-9e98-5afcbf6b33fd","type":"LegendItem"},{"attributes":{"children":[{"id":"ffaef986-93f4-43b8-a120-476c7e3042be","type":"Row"}]},"id":"52f841d9-b0c2-4fdc-aa2f-5bc5fb5d6b64","type":"Column"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[61]},"y":{"__ndarray__":"...","dtype":"float64","shape":[61]}}},"id":"19766cf0-927c-4a02-8844-b06cce4b082f","type":"ColumnDataSource"},{"attributes":{"line_color":{"value":"#0087ff"},"line_dash":[4,0],"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"140db8fd-5843-482f-8542-5fe7c081fc8e","type":"Line"},{"attributes":{"dimension":1,"plot":{"id":"73ad1312-781f-4f8b-91f1-28d79e00514b","subtype":"Figure","type":"Plot"},"ticker":{"id":"f157cf35-8550-4f23-aa21-a4eccfc2ea5b","type":"LogTicker"}},"id":"0afb4b03-a9d5-450f-b002-0b21d57de852","type":"Grid"},{"attributes":{"items":[{"id":"3923af6b-e6a3-424e-aee5-562bc5fcaa12","type":"LegendItem"},{"id":"bd2138a7-339b-4a7c-9e98-5afcbf6b33fd","type":"LegendItem"}],"plot":{"id":"b2cf51d3-7d34-464c-a1d4-8145e2158b87","subtype":"Figure","type":"Plot"}},"id":"ffb4c7b9-adb1-41ce-aa3b-1cc95705a52e","type":"Legend"},{"attributes":{},"id":"e24dd28c-c5b3-4dea-bfe1-1ebfa5dde831","type":"BasicTicker"},{"attributes":{"num_minor_ticks":10},"id":"1fd62fb4-c738-4f9e-834d-d607a4613813","type":"LogTicker"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"AAAAAAAAAACX5IBdTZ6iP+FDiZY8nrI/LLZJRWPtuz88FAX6RJ7CPwd96e3PRcc/LLZJRWPtyz98D5ccd0rQPw4sR8hAntI/oUj3cwry1D8Hfentz0XXP5qZmZmZmdk/","dtype":"float64","shape":[12]},"y":{"__ndarray__":"x7q4jQbwhj8Zuhk7z0KFP3avI6b1y4A/TQLLPkVWdj9dkaFegEpqP1olNjLfZ1s/HJ6EiaVpSj9a0rciH8U5P++XNoQSsyw/MHfaFZVyIz/9WMyVMFQgP28RnwxwbR4/","dtype":"float64","shape":[12]}}},"id":"2125c336-48dd-46ed-81d3-d7e9bc162c19","type":"ColumnDataSource"},{"attributes":{"ticker":null},"id":"a7f4db3c-fd5e-4824-8e4a-c58402ab540e","type":"LogTickFormatter"},{"attributes":{"plot":{"id":"b2cf51d3-7d34-464c-a1d4-8145e2158b87","subtype":"Figure","type":"Plot"}},"id":"71603259-aeca-405f-9762-3c8939849138","type":"HelpTool"},{"attributes":{"axis_label":"q (1/A)","formatter":{"id":"ac98e002-c0ca-4192-90f7-5e23d9d4df22","type":"BasicTickFormatter"},"plot":{"id":"b2cf51d3-7d34-464c-a1d4-8145e2158b87","subtype":"Figure","type":"Plot"},"ticker":{"id":"d3a711f4-aa59-4bb3-8648-1e570519b1b9","type":"BasicTicker"}},"id":"e87303ae-1b78-4548-bd45-ed00487e60ba","type":"LinearAxis"},{"attributes":{"plot":{"id":"b2cf51d3-7d34-464c-a1d4-8145e2158b87","subtype":"Figure","type":"Plot"}},"id":"90470bfe-5eb1-42f0-bee9-55a00743c08a","type":"WheelZoomTool"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"AAAAAAAAAACX5IBdTZ6iP+FDiZY8nrI/LLZJRWPtuz88FAX6RJ7CPwd96e3PRcc/LLZJRWPtyz98D5ccd0rQPw4sR8hAntI/oUj3cwry1D8Hfentz0XXP5qZmZmZmdk/","dtype":"float64","shape":[12]},"y":{"__ndarray__":"x7q4jQbwhj8Zuhk7z0KFP3avI6b1y4A/TQLLPkVWdj9dkaFegEpqP1olNjLfZ1s/HJ6EiaVpSj9a0rciH8U5P++XNoQSsyw/MHfaFZVyIz/9WMyVMFQgP28RnwxwbR4/","dtype":"float64","shape":[12]}}},"id":"3937d9ab-7469-4981-af83-e3cc20be2e3f","type":"ColumnDataSource"},{"attributes":{},"id":"a286dc18-4cfe-4201-8f41-8670b95c92f0","type":"ToolEvents"},{"attributes":{"plot":{"id":"b2cf51d3-7d34-464c-a1d4-8145e2158b87","subtype":"Figure","type":"Plot"},"ticker":{"id":"d3a711f4-aa59-4bb3-8648-1e570519b1b9","type":"BasicTicker"}},"id":"4a64e5c7-ebe3-429b-b5a9-ba2100d5fdcb","type":"Grid"},{"attributes":{"axis_label":"I(q)","formatter":{"id":"f6f7b11b-d385-4c8d-9eb0-280d30421795","type":"BasicTickFormatter"},"plot":{"id":"b2cf51d3-7d34-464c-a1d4-8145e2158b87","subtype":"Figure","type":"Plot"},"ticker":{"id":"e24dd28c-c5b3-4dea-bfe1-1ebfa5dde831","type":"Basi ...

# %% [markdown]
# ## Comaparison to a grid scan of the ellipsoid dimensions: <br/> 20.5-24.5 A x 13-17 A x 13-17 A

# %%
import sasmol.sasmol as sasmol
atom = sasmol.SasMol(0)
atom.read_pdb('data/lysozyme_centered.pdb')
atom_rg = atom.calcrg(0)

model = sasmol.SasMol(0)
model.read_pdb('lys_ellipsoid/lys_ellipsoid_z.pdb')
model_rg = model.calcrg(0)

logging.debug('atomistic Rg: {}'.format(atom_rg))
logging.debug('model Rg: {}'.format(model_rg))
# Out:
# reading filename:  data/lysozyme_centered.pdb
# num_atoms =  1960
# >>> found  1  model(s) or frame(s)
# finished reading frame =  1
# reading filename:  lys_ellipsoid/lys_ellipsoid_z.pdb
# num_atoms =  2000
# >>> found
# DEBUG: atomistic Rg: 13.9946706991
# DEBUG: model Rg: 13.8646412507
#  1  model(s) or frame(s)
# finished reading frame =  1

# %%
import pandas as pd
run_dir = 'lys_ellipsoid_scan1'

# %% [markdown]
# dimensions and Radius of Gyration for each of the generated ellipsoids

# %%
log_fname = os.path.join(run_dir, 'sx13to17_sy13to17_sz20.5to24.5.log')
log = pd.read_csv(log_fname, delimiter='\t', index_col=[0], escapechar='#')
log.rename(columns=lambda x: x.strip(), inplace=True)

# %%
log.head()
# Out:
#                 rg    sx    sy    sz
#  frame
# 1        12.320748  13.0  13.0  20.5
# 2        12.507873  13.0  14.0  20.5
# 3        12.706000  13.0  15.0  20.5
# 4        13.069334  13.0  16.0  20.5
# 5        13.311778  13.0  17.0  20.5

# %% [markdown]
# R-factor and filename for the theoretical I(Q) of each of the generated ellipsoids

# %%
r_fname = os.path.join(run_dir, 'sascalc_12/neutron_D2Op_100/nq_12_r_factors.txt')
r = pd.read_csv(r_fname, delimiter='\t', index_col=[0])
r.rename(columns=lambda x: x.strip(), inplace=True)

# %%
r.head()
# Out:
#           r     scale                                             fnames
# 1  0.049451  0.011101  ./lys_ellipsoid_scan1/sascalc_12/neutron_D2Op_...
# 2  0.042831  0.011125  ./lys_ellipsoid_scan1/sascalc_12/neutron_D2Op_...
# 3  0.039164  0.011149  ./lys_ellipsoid_scan1/sascalc_12/neutron_D2Op_...
# 4  0.036621  0.011196  ./lys_ellipsoid_scan1/sascalc_12/neutron_D2Op_...
# 5  0.047032  0.011228  ./lys_ellipsoid_scan1/sascalc_12/neutron_D2Op_...

# %% [markdown]
# combined results

# %%
result = pd.concat([log, r], axis=1)

# %%
result.head()
# Out:
#                 rg    sx    sy    sz         r     scale  \
#  frame
# 1        12.320748  13.0  13.0  20.5  0.049451  0.011101
# 2        12.507873  13.0  14.0  20.5  0.042831  0.011125
# 3        12.706000  13.0  15.0  20.5  0.039164  0.011149
# 4        13.069334  13.0  16.0  20.5  0.036621  0.011196
# 5        13.311778  13.0  17.0  20.5  0.047032  0.011228
#
#                                                     fnames
#  frame
# 1        ./lys_ellipsoid_scan1/sascalc_12/neutron_D2Op_...
# 2        ./lys_ellipsoid_scan1/sascalc_12/neutron_D2Op_...
# 3        ./lys_ellipsoid_scan1/sascalc_12/neutron_D2Op_...
# 4        ./lys_ellipsoid_scan1/sascalc_12/neutron_D2Op_...
# 5        ./lys_ellipsoid_scan1/sascalc_12/neutron_D2Op_...

# %%
i_best = result['r'].idxmin()
i_worst = result['r'].idxmax()
logging.info('\nbest: {}\nworst: {}'.format(i_best, i_worst))
# Out:
# INFO:
# best: 76
# worst: 125

# %% [markdown]
# ### The best parameters

# %%
result.loc[i_best]
# Out:
# rg                                                  13.3488
# sx                                                       13
# sy                                                       13
# sz                                                     23.5
# r                                                 0.0248975
# scale                                             0.0112296
# fnames    ./lys_ellipsoid_scan1/sascalc_12/neutron_D2Op_...
# Name: 76, dtype: object

# %% [markdown]
# ### The worst parameters

# %%
result.loc[i_worst]
# Out:
# rg                                                  15.3821
# sx                                                       17
# sy                                                       17
# sz                                                     24.5
# r                                                  0.166328
# scale                                             0.0115277
# fnames    ./lys_ellipsoid_scan1/sascalc_12/neutron_D2Op_...
# Name: 125, dtype: object

# %% [markdown]
# ### Load and Plot the theoretical scattering

# %%
len(iq_goal)
# Out:
# 12

# %%
iq_data = np.empty((len(iq_goal), len(result)+1), order='F')
iq_data[:, 0] = iq_goal[:, 0]
for i in xrange(len(result)):
    this_iq_data = np.loadtxt(result.fnames.iloc[i])
    iq_data[:, i+1] = this_iq_data[:, 1] * iq_goal[0, 1] / this_iq_data[0, 1]

# %%
def errorbar(fig, x, y, xerr=None, yerr=None, color='red', 
             point_kwargs={}, error_kwargs={}):

    fig.circle(x, y, color=color, **point_kwargs)

    if xerr is not None:
        x_err_x = []
        x_err_y = []
        for px, py, err in zip(x, y, xerr):
            x_err_x.append((px - err, px + err))
            x_err_y.append((py, py))
        fig.multi_line(x_err_x, x_err_y, color=color, **error_kwargs)

    if yerr is not None:
        y_err_x = []
        y_err_y = []
        for px, py, err in zip(x, y, yerr):
            y_err_x.append((px, px))
            y_err_y.append((py - err, py + err))
        fig.multi_line(y_err_x, y_err_y, color=color, **error_kwargs)

# %%
result.loc[i_best].sz
# Out:
# 23.5

# %%
p1 = Scatter(result, x='rg', y='r', color=palette[1], width=400, height=400, 
             xlabel='Rg (A)', ylabel='R-factor')
vline = Span(location=atom_rg, dimension='height', line_color=palette[0], line_width=3)
p1.renderers.extend([vline])

p2 = figure(width=400, height=400, x_axis_label='q (1/A)', y_axis_label='I(q)') #, x_axis_type='log', y_axis_type='log')

#for i in result.index:
#    p2.line(iq_data[:, 0], iq_data[:, i], color='black', line_width=2, legend='scan')
errorbar(p2, iq_goal[:, 0], iq_goal[:, 1], yerr=iq_goal[:, 1]*0.01, color=palette[0], 
         point_kwargs={'legend': 'atomistic PDB'})
p2.line(iq_data[:, 0], iq_data[:, i_best], color=palette[1], line_width=2, line_dash=[5, 1], 
        legend='best: {}x{}x{}'.format(result.loc[i_best].sz, result.loc[i_best].sx, result.loc[i_best].sy))
p2.line(iq_model[:, 0], iq_model[:, 1], color=palette[2], line_width=2, 
        legend='Liu: 22.5x15x15')
p2.line(iq_data[:, 0], iq_data[:, i_worst], color=palette[3], line_width=2, line_dash=[4, 2, 2], 
        legend='worst')

plots = gridplot([[p1, p2]])
show(plots)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a23dbc69-c377-43a1-b0a8-7b529a201a4f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("a23dbc69-c377-43a1-b0a8-7b529a201a4f");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a23dbc69-c377-43a1-b0a8-7b529a201a4f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a23dbc69-c377-43a1-b0a8-7b529a201a4f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"779ff075-99f7-4383-98e7-db7f73a41ef6":{"roots":{"references":[{"attributes":{"plot":{"id":"b0f6d56f-b91a-4094-b244-fe275beb35fb","subtype":"Figure","type":"Plot"}},"id":"af88898b-bbef-476c-9b90-1fa2de7acfb5","type":"PanTool"},{"attributes":{"label":{"value":"best: 23.5x13.0x13.0"},"renderers":[{"id":"bd53b590-ed5f-42b9-bc8a-0abd772b5247","type":"GlyphRenderer"}]},"id":"c5ea80f8-79dc-4300-a8c9-f8565bd6c6b5","type":"LegendItem"},{"attributes":{"fill_alpha":{"value":0.7},"fill_color":{"value":"#d70000"},"line_color":{"value":"#d70000"},"size":{"units":"screen","value":8},"x":{"field":"x_values"},"y":{"field":"y_values"}},"id":"9e9d9ea5-c5f4-4e28-90d4-1c8f08af6e1b","type":"Circle"},{"attributes":{"data_source":{"id":"4cc0930f-7965-41c1-ad5c-0b76fb5eeadb","type":"ColumnDataSource"},"glyph":{"id":"0d5b1e80-d889-4b2d-9741-a8e870bd6af6","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"4d054b58-a6da-4a9c-a9ab-153da76bcf67","type":"Line"},"selection_glyph":null},"id":"33ffeaa9-3b0a-4746-9a01-5522deb56564","type":"GlyphRenderer"},{"attributes":{"children":[{"id":"338e4ed1-552f-4be4-8682-fc3ec8c1d739","type":"ToolbarBox"},{"id":"641d49a5-86b1-4947-9cb9-5594c535a776","type":"Column"}]},"id":"7a676ebc-f321-4235-a984-5cc9791d7783","type":"Column"},{"attributes":{"line_color":{"value":"#0087ff"},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"ff2b9a8b-90de-46f0-9f8a-cf709cff2b5d","type":"MultiLine"},{"attributes":{"data_source":{"id":"ba9a1074-220c-49b4-97a8-39739299bbe4","type":"ColumnDataSource"},"glyph":{"id":"dd3595d8-5fbb-430f-8594-7581e99cdca5","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"f32e3a60-4914-4f6d-ad83-1a28ebd03d56","type":"Circle"},"selection_glyph":null},"id":"08af5423-a5b7-4c3c-ad07-9ef0d0a2f02e","type":"GlyphRenderer"},{"attributes":{"overlay":{"id":"ae52070d-c4c8-4d39-b6da-c3693ce97e3a","type":"BoxAnnotation"},"plot":{"id":"b0f6d56f-b91a-4094-b244-fe275beb35fb","subtype":"Figure","type":"Plot"}},"id":"442932f4-37b1-4ba4-af41-0cbf09bfe9e5","type":"BoxZoomTool"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_dash":[5,1],"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"ab8615b6-13e5-441e-aa0e-ffd0e570ae3c","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"xs":{"field":"xs"},"ys":{"field":"ys"}},"id":"f2c0c645-ba3f-4b82-be27-1737cff71bef","type":"MultiLine"},{"attributes":{"plot":{"id":"67cc39cf-265c-4acf-8564-99873544df39","subtype":"Chart","type":"Plot"},"ticker":{"id":"9faa2110-f195-4f78-9574-c61e8695c365","type":"BasicTicker"}},"id":"b82aedc8-ff0c-4cae-a43e-e2df7944e192","type":"Grid"},{"attributes":{"dimension":"height","line_color":{"value":"#0087ff"},"line_width":{"value":3},"location":13.99467069905708,"plot":null},"id":"142a00d0-072d-4c68-b2f0-0708a458aaf7","type":"Span"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"bb3e6092-2293-431f-85c2-088cc37e40f5","type":"BoxAnnotation"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":{"__ndarray__":"AAAAAAAAAACX5IBdTZ6iP+FDiZY8nrI/LLZJRWPtuz88FAX6RJ7CPwd96e3PRcc/LLZJRWPtyz98D5ccd0rQPw4sR8hAntI/oUj3cwry1D8Hfentz0XXP5qZmZmZmdk/","dtype":"float64","shape":[12]},"y":{"__ndarray__":"x7q4jQbwhj++M0hseDSFP1Zshc3dvoA/jUNzGOmQdj9g96JpTOlpP+Xo6528TVk/uY8JZRvgRD9TY4cOSJ0sPx+YPpwJSxE/T34zu3MLAj/ysrzoOCkGP/1lAsUZkQk/","dtype":"float64","shape":[12]}}},"id":"ac592435-e8db-40d4-81e2-e829390794cd","type":"ColumnDataSource"},{"attributes":{"label":{"value":"Liu: 22.5x15x15"},"renderers":[{"id":"d676ad2c-5d03-4049-8786-818fcf338eef","type":"GlyphRenderer"}]},"id":"21f40348-a7f3-49f1-baf7-e635decc7c09","type":"LegendItem"},{"attributes":{},"id":"75c ...

# %%
iq_goal_fname = 'data/exp_lys/1mgml_lys_sans.dat'
assert os.path.exists(iq_goal_fname)
iq_goal = np.loadtxt(iq_goal_fname)

# %%
iq_goal[0, 1] *= 0.97

# %%
iq_goal[:, 1:] /= iq_goal[0, 1]
iq_goal
# Out:
# array([[ 0.        ,  1.        ,  0.01775931,  0.        ],
#        [ 0.02704   ,  0.96974258,  0.06277236,  0.45597024],
#        [ 0.03053   ,  0.97180772,  0.03643743,  0.46014367],
#        [ 0.03403   ,  0.96755135,  0.03721663,  0.46511628],
#        [ 0.03754   ,  0.95585373,  0.03170142,  0.47079926],
#        [ 0.04105   ,  0.91650586,  0.03309358,  0.47701502],
#        [ 0.04457   ,  0.88374945,  0.02983365,  0.48385235],
#        [ 0.04809   ,  0.8558468 ,  0.0289935 ,  0.49113367],
#        [ 0.05161   ,  0.84126801,  0.02740832,  0.49894776],
#        [ 0.2113    ,  0.04889169,  0.0190737 ,  1.09042152],
#        [ 0.2147    ,  0.03365538,  0.018155  ,  1.10551693],
#        [ 0.2181    ,  0.03949541,  0.01822862,  1.12061234],
#        [ 0.2215    ,  0.0180903 ,  0.0175791 ,  1.13481979],
#        [ 0.2248    ,  0.02749098,  0.01888425,  1.1499152 ],
#        [ 0.2282    ,  0.01220331,  0.01897854,  1.16412265],
#        [ 0.2315    ,  0.02099782,  0.01889283,  1.17921806],
#        [ 0.2349    ,  0.01753989,  0.02076559,  1.19431347],
#        [ 0.2382    ,  0.03225958,  0.02159434,  1.20852092],
#        [ 0.2416    ,  0.01244254,  0.02091382,  1.22361633],
#        [ 0.2449    ,  0.02193715,  0.021851  ,  1.23871174],
#        [ 0.2482    , -0.00994446,  0.01995203,  1.25291919],
#        [ 0.2516    ,  0.01006044,  0.0236075 ,  1.2680146 ],
#        [ 0.2549    ,  0.00861767,  0.01980765,  1.28311001],
#        [ 0.2582    ,  0.02613775,  0.02100804,  1.29731746],
#        [ 0.2615    ,  0.02829381,  0.02137559,  1.31241287],
#        [ 0.2648    ,  0.01161033,  0.02091941,  1.32662031],
#        [ 0.2681    ,  0.00450661,  0.0212713 ,  1.34171573],
#        [ 0.2714    ,  0.02310691,  0.02176343,  1.35681114],
#        [ 0.2747    ,  0.00544593,  0.02178536,  1.37101859],
#        [ 0.2779    , -0.02148801,  0.02074796,  1.386114  ],
#        [ 0.2812    ,  0.00464751,  0.02011702,  1.40032144],
#        [ 0.2845    ,  0.01286963,  0.02148302,  1.41541686],
#        [ 0.2877    ,  0.02358537,  0.0222383 ,  1.4296243 ],
#        [ 0.291     , -0.00521405,  0.02035802,  1.44471971],
#        [ 0.2942    ,  0.02007168,  0.02372068,  1.45892716],
#        [ 0.2975    ,  0.01231043,  0.02163276,  1.47402257],
#        [ 0.3007    ,  0.00118518,  0.02197756,  1.48823002],
#        [ 0.3039    ,  0.00090778,  0.02081522,  1.50332543],
#        [ 0.3071    , -0.03335154,  0.0233039 ,  1.51753288],
#        [ 0.3103    ,  0.00895522,  0.02121997,  1.53262829],
#        [ 0.3135    , -0.02129575,  0.02291578,  1.54683574],
#        [ 0.3167    ,  0.01268616,  0.02203327,  1.56104318],
#        [ 0.3199    ,  0.01040239,  0.02122079,  1.57613859],
#        [ 0.3231    , -0.01582706,  0.02169398,  1.59034604],
#        [ 0.3263    ,  0.01147822,  0.02093437,  1.60455349],
#        [ 0.3294    ,  0.0049293 ,  0.02246995,  1.6196489 ],
#        [ 0.3326    , -0.00680651,  0.02200145,  1.63385634],
#        [ 0.3358    ,  0.00128351,  0.01989016,  1.64806379],
#        [ 0.3389    ,  0.00058341,  0.02199999,  1.66227124],
#        [ 0.342     ,  0.00469447,  0.02221054,  1.67647868],
#        [ 0.3452    , -0.01651837,  0.02268422,  1.6915741 ],
#        [ 0.3483    ,  0.00203497,  0.02271546,  1.70578154],
#        [ 0.3514    , -0.00156386,  0.02001522,  1.71998899],
#        [ 0.3545    ,  0.02876787,  0.02532714,  1.73419644],
#        [ 0.3576    ,  0.00305944,  0.02455667,  1.74840388],
#        [ 0.3607    , -0.02867688,  0.02763603,  1.76261133],
#        [ 0.3638    , -0.03947776,  0.02950255,  1.77681878],
#        [ 0.3669    , -0.01867443,  0.03002875,  1.79102622],
#        [ 0.37      ,  0.01465435,  0.03788885,  1.80523367],
#        [ 0.373     , -0.03254432,  0.03890987,  1.81855315],
#        [ 0.3761    ,  0.0026969 ,  0.03764421,  1.8327606 ],
#        [ 0.3791    , -0.0397038 ,  0.04470895,  1.84696804],
#        [ 0.3822    ,  0.00100611,  0.04479782,  1.86117549],
#        [ 0.3852    ,  0.05144106,  0.05234332,  1.87538294],
#        [ 0.3882    , -0.00698998,  0.0569723 ,  1.88870242],
#        [ 0.3912    , -0.01615583,  0.07382987,  1.90290986],
#        [ 0.3943    ,  0.01371503,  0.05469155,  1.91711731],
#        [ 0.3973    , -0.0840433 ,  0.0791454 ,  1.93043679]])

# %%
q1 = iq_data[1, 0]

# %%
np.argmin(np.abs(iq_goal[:10, 0] - q1))
# Out:
# 4

# %%
p1 = figure(width=400, height=400, x_axis_label='q (1/A)', y_axis_label='I(q)', 
            title='Scale to I(0)') #, x_axis_type='log', y_axis_type='log')

for i in result.index:
    p1.line(iq_data[:, 0], iq_data[:, i]/iq_data[0, i], color='black', line_width=2, legend='scan', alpha=0.1)

errorbar(p1, iq_goal[:, 0], iq_goal[:, 1], yerr=iq_goal[:, 2], color=palette[0], 
         point_kwargs={'legend': 'experimental data'})

p1.line(iq_data[:, 0], iq_data[:, i_best]/iq_data[0, i_best], color=palette[1], line_width=2, line_dash=[5, 1], 
        legend='best: {}x{}x{}'.format(result.loc[i_best].sz, result.loc[i_best].sx, result.loc[i_best].sy))

p1.line(iq_data[:, 0], iq_data[:, i_worst]/iq_data[0, i_worst], color=palette[3], line_width=2, line_dash=[4, 2, 2], 
        legend='worst: {}x{}x{}'.format(result.loc[i_worst].sz, result.loc[i_worst].sx, result.loc[i_worst].sy))

q1 = iq_data[1, 0]
i_match = np.argmin(np.abs(iq_goal[:10, 0] - q1))
scale = iq_goal[i_match, 1] / iq_data[1, 1]

p2 = figure(width=400, height=400, x_axis_label='q (1/A)', y_axis_label='I(q)', 
            title='Scale to I(Q1)') #, x_axis_type='log', y_axis_type='log')

for i in result.index:
    p2.line(iq_data[:, 0], iq_data[:, i]*scale, color='black', line_width=2, legend='scan', alpha=0.1)

errorbar(p2, iq_goal[:, 0], iq_goal[:, 1], yerr=iq_goal[:, 2], 
         color=palette[0], 
         point_kwargs={'legend': 'atomistic PDB'})

p2.line(iq_data[:, 0], iq_data[:, i_best]*scale, color=palette[1], line_width=2, line_dash=[5, 1], 
        legend='best: {}x{}x{}'.format(result.loc[i_best].sz, result.loc[i_best].sx, result.loc[i_best].sy))

p2.line(iq_data[:, 0], iq_data[:, i_worst]*scale, color=palette[3], line_width=2, line_dash=[4, 2, 2], 
        legend='worst: {}x{}x{}'.format(result.loc[i_worst].sz, result.loc[i_worst].sx, result.loc[i_worst].sy))


plots = gridplot([[p1, p2]])
show(plots)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="37cd926b-0022-4718-8d85-7b8e45c37862"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("37cd926b-0022-4718-8d85-7b8e45c37862");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("