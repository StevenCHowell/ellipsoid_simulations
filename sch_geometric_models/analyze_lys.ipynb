# %% [markdown]
# # Lysozyme PDB
# ## Determine ellipsoid geometry that will reproduce the theoretical scattering of the Lysozyme PDB (lysozyme_centered.pdb)

# %%
from bokeh.plotting import figure, output_notebook, show
from bokeh.models import Range1d, Span
from bokeh.palettes import Colorblind8 as palette
from bokeh.layouts import gridplot
from bokeh.charts import Scatter

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d6163bc7-059d-4ebb-a1f9-3cc6f580cd76">Loading BokehJS ...</span>
#     </div>

# %%
import logging
logging.basicConfig(format='%(levelname)s: %(message)s', level=logging.DEBUG)

# %%
import os
import sys
import numpy as np

# %% [markdown]
# ## Comaparison to the 22.5 A x 15 A x 15 A ellipsoid
# The plots below compare the theoretical scattering from the Lysozyme PDB (`lysozyme_centered.pdb`) and an ellipsoid with dimensions matching what Monica cited from Yun Liu.

# %% [markdown]
# theoretical scattering from the PDB

# %%
iq_goal_fname = 'data/lysozyme_00001.iq'
assert os.path.exists(iq_goal_fname)
iq_goal = np.loadtxt(iq_goal_fname)

# %% [markdown]
# theoretical scattering from Yun Liu's ellipsoid definition (22.5 A x 15 A x 15 A)

# %%
iq_model_fname = 'lys_ellipsoid/lys_ellipsoid_00001.iq'
assert os.path.exists(iq_model_fname)
iq_model = np.loadtxt(iq_model_fname)

# %%
p2 = figure(width=400, height=400, x_axis_label='q (1/A)', y_axis_label='I(q)', x_axis_type='log', y_axis_type='log')
p1 = figure(width=400, height=400, x_axis_label='q (1/A)', y_axis_label='I(q)')

p1.line(iq_goal[:, 0], iq_goal[:, 1], color=palette[0], line_width=2, line_dash=[4, 0], legend='experiment')
p1.line(iq_model[:, 0], iq_model[:, 1], color=palette[1], line_width=2, line_dash=[4, 4], legend='22.5x15x15 model')
p2.line(iq_goal[:, 0], iq_goal[:, 1], color=palette[0], line_width=2, line_dash=[4, 0], legend='experiment')
p2.line(iq_model[:, 0], iq_model[:, 1], color=palette[1], line_width=2, line_dash=[4, 4], legend='22.5x15x15 model')

x_range = (iq_goal[1, 0], iq_goal[-1, 0])
y_range = (min(iq_goal[:, 1]) * 0.5, max(iq_goal[:, 1]) * 1.1)
logging.debug('x range: {}'.format(x_range))
logging.debug('y range: {}'.format(y_range))
p1.x_range = Range1d(*x_range)
p1.y_range = Range1d(*y_range)
p2.x_range = p1.x_range
p2.y_range = p1.y_range
p2.legend.location = 'bottom_left'

plots = gridplot([[p1, p2]])
show(plots)
# Out:
# DEBUG: x range: (0.0050000000000000001, 0.29999999999999999)
# DEBUG: y range: (0.0038509999999999998, 1.1000000000000001)
#     <div class="bk-root">
#         <div class="plotdiv" id="b959634c-b19a-4869-9cb4-34a17faa3464"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#b959634c-b19a-4869-9cb4-34a17faa3464").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b959634c-b19a-4869-9cb4-34a17faa3464");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b959634c-b19a-4869-9cb4-34a17faa3464' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"d092bb1b-ec97-47b1-8be5-a78d9b04fe74":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.0,0.005,0.01,0.015,0.02,0.025,0.03,0.035,0.04,0.045,0.05,0.055,0.06,0.065,0.07,0.075,0.08,0.085,0.09,0.095,0.1,0.105,0.11,0.115,0.12,0.125,0.13,0.135,0.14,0.145,0.15,0.155,0.16,0.165,0.17,0.175,0.18,0.185,0.19,0.195,0.2,0.205,0.21,0.215,0.22,0.225,0.23,0.235,0.24,0.245,0.25,0.255,0.26,0.265,0.27,0.275,0.28,0.285,0.29,0.295,0.3],"y":[1.0,0.9984,0.993613,0.985682,0.974675,0.96069,0.943847,0.924291,0.902188,0.877725,0.851103,0.822542,0.792269,0.760522,0.727546,0.693586,0.658891,0.623705,0.588266,0.552805,0.517545,0.482693,0.448445,0.414981,0.382461,0.351032,0.320819,0.291929,0.264451,0.238454,0.213989,0.191088,0.169768,0.150028,0.131855,0.11522,0.100082,0.086392,0.074089,0.063106,0.05337,0.044803,0.037325,0.030852,0.025301,0.020589,0.016635,0.013359,0.010685,0.008542,0.00686,0.005576,0.004631,0.003972,0.003548,0.003316,0.003236,0.003275,0.003401,0.003588,0.003815]}},"id":"afb85da5-aa47-47e4-b5c7-040afd6dfd67","type":"ColumnDataSource"},{"attributes":{"label":{"value":"experiment"},"renderers":[{"id":"bd2c9b9e-213d-407d-8f39-fdd5bc19bbd2","type":"GlyphRenderer"}]},"id":"0b0a1d3c-b7b3-44df-94af-febb56d2f8d4","type":"LegendItem"},{"attributes":{"items":[{"id":"0b0a1d3c-b7b3-44df-94af-febb56d2f8d4","type":"LegendItem"},{"id":"aeb50070-3dee-4800-9d92-ecbe0570384d","type":"LegendItem"}],"plot":{"id":"5d3cf2cb-5cca-4c61-9087-e0392712c038","subtype":"Figure","type":"Plot"}},"id":"d3c2eff1-d843-4b4c-8872-fd934b655d63","type":"Legend"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a5302629-4def-4386-9b11-95c543565e8f","type":"BoxAnnotation"},{"attributes":{"ticker":null},"id":"96b5d967-597f-48a1-94b3-bcc4196595e3","type":"LogTickFormatter"},{"attributes":{"data_source":{"id":"adb2ecbb-4ba5-47bf-a144-3485e955592b","type":"ColumnDataSource"},"glyph":{"id":"6720a1e9-5f24-4a0e-8fff-685cc85c3b42","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"52a3b5e0-a538-4019-b81b-9d25b4f904a5","type":"Line"},"selection_glyph":null},"id":"bd2c9b9e-213d-407d-8f39-fdd5bc19bbd2","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"b4f59921-a995-4f4b-ac8d-f3dbfc0bace5","type":"LogAxis"}],"left":[{"id":"7705adf0-b133-47d9-9aa2-dd578faa3783","type":"LogAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"b4f59921-a995-4f4b-ac8d-f3dbfc0bace5","type":"LogAxis"},{"id":"ff737798-4668-4aca-9946-f86907019a94","type":"Grid"},{"id":"7705adf0-b133-47d9-9aa2-dd578faa3783","type":"LogAxis"},{"id":"682ee237-356b-4177-8b8d-7e357cc03177","type":"Grid"},{"id":"46487adb-af67-44ce-a75b-b3cb9af42a7a","type":"BoxAnnotation"},{"id":"276fa1aa-ef5d-408f-99d6-7973bb43132a","type":"Legend"},{"id":"f068b19d-1a97-45d1-87c2-4295be70b356","type":"GlyphRenderer"},{"id":"1a077738-994c-49ba-b9bb-871c7b423182","type":"GlyphRenderer"}],"title":{"id":"de481c69-4c4b-4271-bcf3-7d97df4f3c17","type":"Title"},"tool_events":{"id":"0d6a10d0-18be-4d22-8d14-f55040920406","type":"ToolEvents"},"toolbar":{"id":"b0fd57a3-1756-4af7-916f-8739f1dcb32f","type":"Toolbar"},"toolbar_location":null,"x_mapper_type":"log","x_range":{"id":"fd981d57-8f1b-44cf-9947-429f97c12e51","type":"Range1d"},"y_mapper_type":"log","y_range":{"id":"b11d8de2-f6a6-41e3-b2d4-2fae5e7162ac","type":"Range1d"}},"id":"e0022f2b-5cb9-4024-8d96-61320124984c","subtype":"Figure","type":"Plot"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":[0.0,0.005,0.01,0.015,0.02,0.025,0.03,0.035,0.04,0.045,0.05,0.055,0.06,0.065,0.07,0.075,0.08,0.085,0.09,0.095,0.1,0.105,0.11,0.115,0.12,0.125,0.13,0.135,0.14,0.145,0.15,0.155,0.16,0.165,0.17,0.175,0.18,0.185,0.19,0.195,0.2,0.205,0.21, ...

# %% [markdown]
# ## Comaparison to a grid scan of the ellipsoid dimensions: <br/> 20.5-24.5 A x 13-17 A x 13-17 A

# %%
import sasmol.sasmol as sasmol
atom = sasmol.SasMol(0)
atom.read_pdb('data/lysozyme_centered.pdb')
atom_rg = atom.calcrg(0)

model = sasmol.SasMol(0)
model.read_pdb('lys_ellipsoid/lys_ellipsoid_z.pdb')
model_rg = model.calcrg(0)

logging.debug('atomistic Rg: {}'.format(atom_rg))
logging.debug('model Rg: {}'.format(model_rg))
# Out:
# DEBUG: atomistic Rg: 13.9946706991
# DEBUG: model Rg: 13.8646412507
# reading filename:  data/lysozyme_centered.pdb
# num_atoms =  1960
# >>> found  1  model(s) or frame(s)
# finished reading frame =  1
# reading filename:  lys_ellipsoid/lys_ellipsoid_z.pdb
# num_atoms =  2000
# >>> found  1  model(s) or frame(s)
# finished reading frame =  1

# %%
import pandas as pd
run_dir = 'lys_ellipsoid_scan1'

# %% [markdown]
# dimensions and Radius of Gyration for each of the generated ellipsoids

# %%
log_fname = os.path.join(run_dir, 'sx13to17_sy13to17_sz20.5to24.5.log')
log = pd.read_csv(log_fname, delimiter='\t', index_col=[0], escapechar='#')
log.rename(columns=lambda x: x.strip(), inplace=True)

# %%
log.head()
# Out:
#                 rg    sx    sy    sz
#  frame
# 1        12.320748  13.0  13.0  20.5
# 2        12.507873  13.0  14.0  20.5
# 3        12.706000  13.0  15.0  20.5
# 4        13.069334  13.0  16.0  20.5
# 5        13.311778  13.0  17.0  20.5

# %% [markdown]
# R-factor and filename for the theoretical I(Q) of each of the generated ellipsoids

# %%
r_fname = os.path.join(run_dir, 'sascalc_61/neutron_D2Op_100/pdb_r_factors.txt')
r = pd.read_csv(r_fname, delimiter='\t', index_col=[0])
r.rename(columns=lambda x: x.strip(), inplace=True)

# %%
r.head()
# Out:
#           r                                             fnames
# 1  0.063434  lys_ellipsoid_scan1/sascalc_61/neutron_D2Op_10...
# 2  0.038537  lys_ellipsoid_scan1/sascalc_61/neutron_D2Op_10...
# 3  0.032567  lys_ellipsoid_scan1/sascalc_61/neutron_D2Op_10...
# 4  0.017184  lys_ellipsoid_scan1/sascalc_61/neutron_D2Op_10...
# 5  0.018528  lys_ellipsoid_scan1/sascalc_61/neutron_D2Op_10...

# %% [markdown]
# combined results

# %%
result = pd.concat([log, r], axis=1)

# %%
result.head()
# Out:
#                 rg    sx    sy    sz         r  \
#  frame
# 1        12.320748  13.0  13.0  20.5  0.063434
# 2        12.507873  13.0  14.0  20.5  0.038537
# 3        12.706000  13.0  15.0  20.5  0.032567
# 4        13.069334  13.0  16.0  20.5  0.017184
# 5        13.311778  13.0  17.0  20.5  0.018528
#
#                                                     fnames
#  frame
# 1        lys_ellipsoid_scan1/sascalc_61/neutron_D2Op_10...
# 2        lys_ellipsoid_scan1/sascalc_61/neutron_D2Op_10...
# 3        lys_ellipsoid_scan1/sascalc_61/neutron_D2Op_10...
# 4        lys_ellipsoid_scan1/sascalc_61/neutron_D2Op_10...
# 5        lys_ellipsoid_scan1/sascalc_61/neutron_D2Op_10...

# %%
i_best = result['r'].idxmin()
i_worst = result['r'].idxmax()
logging.info('\nbest: {}\nworst: {}'.format(i_best, i_worst))
# Out:
# INFO:
# best: 56
# worst: 125

# %% [markdown]
# ### The best parameters

# %%
result.loc[i_best]
# Out:
# rg                                                  13.3364
# sx                                                       14
# sy                                                       13
# sz                                                     22.5
# r                                                0.00630226
# fnames    lys_ellipsoid_scan1/sascalc_61/neutron_D2Op_10...
# Name: 56, dtype: object

# %% [markdown]
# ### The worst parameters

# %%
result.loc[i_worst]
# Out:
# rg                                                  15.3821
# sx                                                       17
# sy                                                       17
# sz                                                     24.5
# r                                                  0.153462
# fnames    lys_ellipsoid_scan1/sascalc_61/neutron_D2Op_10...
# Name: 125, dtype: object

# %% [markdown]
# ### Load and Plot the theoretical scattering

# %%
iq_data = np.empty((len(iq_goal), len(result)+1), order='F')
iq_data[:, 0] = iq_goal[:, 0]
for i in xrange(len(result)):
    this_iq_data = np.loadtxt(result.fnames.iloc[i])
    iq_data[:, i+1] = this_iq_data[:, 1] * iq_goal[0, 1] / this_iq_data[0, 1]

# %%
def errorbar(fig, x, y, xerr=None, yerr=None, color='red', 
             point_kwargs={}, error_kwargs={}):

    fig.circle(x, y, color=color, **point_kwargs)

    if xerr is not None:
        x_err_x = []
        x_err_y = []
        for px, py, err in zip(x, y, xerr):
            x_err_x.append((px - err, px + err))
            x_err_y.append((py, py))
        fig.multi_line(x_err_x, x_err_y, color=color, **error_kwargs)

    if yerr is not None:
        y_err_x = []
        y_err_y = []
        for px, py, err in zip(x, y, yerr):
            y_err_x.append((px, px))
            y_err_y.append((py - err, py + err))
        fig.multi_line(y_err_x, y_err_y, color=color, **error_kwargs)

# %%
result.loc[i_best].sz
# Out:
# 22.5

# %%
p1 = Scatter(result, x='rg', y='r', color=palette[1], width=400, height=400, 
             xlabel='Rg (A)', ylabel='R-factor')
vline = Span(location=atom_rg, dimension='height', line_color=palette[0], line_width=3)
p1.renderers.extend([vline])

p2 = figure(width=400, height=400, x_axis_label='q (1/A)', y_axis_label='I(q)') #, x_axis_type='log', y_axis_type='log')

for i in result.index:
    p2.line(iq_data[:, 0], iq_data[:, i], color='black', line_width=2, legend='scan')
errorbar(p2, iq_goal[:, 0], iq_goal[:, 1], yerr=iq_goal[:, 1]*0.01, color=palette[0], 
         point_kwargs={'legend': 'atomistic PDB'})
p2.line(iq_data[:, 0], iq_data[:, i_best], color=palette[1], line_width=2, line_dash=[5, 1], 
        legend='best: {}x{}x{}'.format(result.loc[i_best].sz, result.loc[i_best].sx, result.loc[i_best].sy))
p2.line(iq_model[:, 0], iq_model[:, 1], color=palette[2], line_width=2, 
        legend='Liu: 22.5x15x15')
p2.line(iq_data[:, 0], iq_data[:, i_worst], color=palette[3], line_width=2, line_dash=[4, 2, 2], 
        legend='worst')

plots = gridplot([[p1, p2]])
show(plots)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="04a73215-5ee1-4182-8ff6-13ee7f7d220a"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#04a73215-5ee1-4182-8ff6-13ee7f7d220a").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("04a73215-5ee1-4182-8ff6-13ee7f7d220a");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '04a73215-5ee1-4182-8ff6-13ee7f7d220a' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"bb3eb7cd-6d0c-4b76-ac2f-b094b36a5126":{"roots":{"references":[{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"5c931133-7955-4580-8afb-4eaab5483d63","type":"Line"},{"attributes":{"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"310cefe6-dafc-427f-871c-b20d2f7e4e0a","type":"Line"},{"attributes":{"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"d7768c1a-4c51-4fe2-8e90-1fd33f965e05","type":"Line"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":[0.0,0.005,0.01,0.015,0.02,0.025,0.03,0.035,0.04,0.045,0.05,0.055,0.06,0.065,0.07,0.075,0.08,0.085,0.09,0.095,0.1,0.105,0.11,0.115,0.12,0.125,0.13,0.135,0.14,0.145,0.15,0.155,0.16,0.165,0.17,0.175,0.18,0.185,0.19,0.195,0.2,0.205,0.21,0.215,0.22,0.225,0.23,0.235,0.24,0.245,0.25,0.255,0.26,0.265,0.27,0.275,0.28,0.285,0.29,0.295,0.3],"y":[1.0,0.998293,0.993188,0.984736,0.973018,0.958147,0.940266,0.919545,0.896177,0.87038,0.842386,0.812447,0.780823,0.747785,0.713605,0.67856,0.64292,0.606951,0.570911,0.535044,0.49958,0.464732,0.430695,0.397644,0.365732,0.33509,0.305829,0.278036,0.251777,0.227098,0.204025,0.182564,0.162705,0.144424,0.127682,0.112427,0.098599,0.08613,0.074944,0.064961,0.056098,0.048273,0.0414,0.035396,0.030181,0.025677,0.021809,0.018508,0.015709,0.013351,0.011379,0.009743,0.008398,0.007303,0.006421,0.005722,0.005176,0.004759,0.00445,0.00423,0.004082]}},"id":"093141bc-f561-4d00-af52-97b105d6df93","type":"ColumnDataSource"},{"attributes":{"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"b4b1ca57-1e10-41c3-9ea3-4c687956c536","type":"Line"},{"attributes":{"plot":{"id":"2b612cc9-84a3-4eab-89e9-d63810c3a7bc","subtype":"Figure","type":"Plot"}},"id":"f35c28f8-a457-4c2f-82b2-9bdee533cd0f","type":"ResetTool"},{"attributes":{"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"bb27d98d-2ba3-4c41-bdf7-9504c34a2c41","type":"Line"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"7dc155b1-f8f3-4162-b6b3-f3fbe0032945","type":"Line"},{"attributes":{"data_source":{"id":"97f7ef4a-9af1-4c76-966e-926a14935d75","type":"ColumnDataSource"},"glyph":{"id":"1eb1d606-9b09-4784-9dd7-42a1bc15193d","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"ba8a2267-776d-4754-a8ed-702fecd3d00f","type":"Line"},"selection_glyph":null},"id":"67cff6a2-67a8-4e9c-8ad7-183c84066833","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"3fcbae10-feba-4a4c-9409-4c5612cbaf72","type":"ColumnDataSource"},"glyph":{"id":"77bdc60a-b8d6-42c5-ad95-e7d1d51d0245","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"d04f0272-a8ce-49f1-afaa-9c03a41730b1","type":"Line"},"selection_glyph":null},"id":"8d0f7d7c-eec2-4130-9fd3-b686f4aecec8","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"c1e1e0e7-2df3-4ee7-a4ad-ccd5434beca3","type":"ColumnDataSource"},"glyph":{"id":"1f8de89b-920f-4493-b6dc-1447539d6f5a","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"fb02a548-3873-471e-b366-7553bf25f87e","type":"Line"},"selection_glyph":null},"id":"ae7bad0b-768c-419d-b1ff-61f47c8f6f78","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"6f84fc89-0167-4037-a2d8-102bb45a9071","type":"ColumnDataSource"},"glyph":{"id":"3ecd41a8-fc17-4203-860c-797c711337a4","type":"Line"},"hover_glyph":null,"nonselection_glyph":{"id":"25a7cc38-7448-4113-9181-2dd058aa923b","type":"Line"},"selection_glyph":null},"id":"58db743d-d199-4166-b141-804901e13f8e","type":"GlyphRenderer"},{"attributes":{"line_color":{"value":"#F0E442"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"c2d80f88-cb0d-4801-a81a-6e97ed79d7b2","type":"Line"},{"attributes":{"label":{"value":"scan"},"renderers":[{"id":"f1221c2d-7d75-4afe-bed7-6205d966b340","type":"GlyphRenderer"},{"id":"b193664f-3b25-4a75-89d7-1697110e569f","type":"Glyp ...

# %% [markdown]
# These Rg values are calculated from the PDBs representing ellipsoids filled with coordinates.  The vertical blue line indicates the atomistic Lysozyme PDB.  The error for the atomistic PDB is 1% of the scattering.
